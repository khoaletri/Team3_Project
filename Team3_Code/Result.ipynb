# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('VOF.L.csv', index_col= 'Date', parse_dates=True, usecols=[0,4])

# %%
df20=pd.read_csv('Result\Result20.csv', index_col='Date', parse_dates=True)
df20
# Out:
#             Close       LNReg      NLNReg       LSTM  Arima     Prophet
# Date
# 2021-12-22  513.0  433.738728  464.157573  513.27124    517  522.466322
# 2021-12-23  510.0  433.876952  464.091742  513.24646    517  523.757213
# 2021-12-24  522.0  434.015177  464.023130  510.34833    517  524.823158
# 2021-12-29  512.0  434.153402  463.951754  515.72205    517  525.998648
# 2021-12-30  516.0  434.291626  463.877631  514.16320    517  527.124485
# ...           ...         ...         ...        ...    ...         ...
# 2022-12-19  453.0  468.018415  409.157083  445.22217    517  561.516167
# 2022-12-20  445.5  468.156640  408.942024  448.52856    517  561.611673
# 2022-12-21  447.0  468.294865  408.727874  447.28055    517  561.786723
# 2022-12-22  443.0  468.433089  408.514638  446.14557    517  562.276952
# 2022-12-23  443.0  468.571314  408.302319  443.52383    517  562.276952
#
# [253 rows x 6 columns]

# %%
plt.figure(figsize=(12,6.5))
plt.plot(df.index, df.Close, label='Observations')
plt.plot(df20.index, df20.LNReg, label='Linear Regression')
plt.plot(df20.index, df20.NLNReg, label='Nonlinear Regression')
plt.plot(df20.index, df20.LSTM, label='LSTM')
plt.plot(df20.index, df20.Arima, label='ARIMA')
plt.plot(df20.index, df20.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df20.Close, label='Observations')
plt.plot(df20.LNReg, label='Linear Regression')
plt.plot(df20.NLNReg, label='Nonlinear Regression')
plt.plot(df20.LSTM, label='LSTM')
plt.plot(df20.Arima, label='ARIMA')
plt.plot(df20.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
df10=pd.read_csv('Result\Result10.csv', index_col='Date', parse_dates=True)

# %%
plt.figure(figsize=(12,6.5))
plt.plot(df.index, df.Close, label='Observations')
plt.plot(df10.index, df10.LNReg, label='Linear Regression')
plt.plot(df10.index, df10.NLNReg, label='Nonlinear Regression')
plt.plot(df10.index, df10.LSTM, label='LSTM')
plt.plot(df10.index, df10.Arima, label='ARIMA')
plt.plot(df10.index, df10.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df10.Close, label='Observations')
plt.plot(df10.LNReg, label='Linear Regression')
plt.plot(df10.NLNReg, label='Nonlinear Regression')
plt.plot(df10.LSTM, label='LSTM')
plt.plot(df10.Arima, label='ARIMA')
plt.plot(df10.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
df30=pd.read_csv('Result\Result10.csv', index_col='Date', parse_dates=True)

# %%
plt.figure(figsize=(12,6.5))
plt.plot(df.index, df.Close, label='Observations')
plt.plot(df30.index, df30.LNReg, label='Linear Regression')
plt.plot(df30.index, df30.NLNReg, label='Nonlinear Regression')
plt.plot(df30.index, df30.LSTM, label='LSTM')
plt.plot(df30.index, df30.Arima, label='ARIMA')
plt.plot(df30.index, df30.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df30.Close, label='Observations')
plt.plot(df30.LNReg, label='Linear Regression')
plt.plot(df30.NLNReg, label='Nonlinear Regression')
plt.plot(df30.LSTM, label='LSTM')
plt.plot(df30.Arima, label='ARIMA')
plt.plot(df30.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
df40=pd.read_csv('Result\Result10.csv', index_col='Date', parse_dates=True)

# %%
plt.figure(figsize=(12,6.5))
plt.plot(df.index, df.Close, label='Observations')
plt.plot(df40.index, df40.LNReg, label='Linear Regression')
plt.plot(df40.index, df40.NLNReg, label='Nonlinear Regression')
plt.plot(df40.index, df40.LSTM, label='LSTM')
plt.plot(df40.index, df40.Arima, label='ARIMA')
plt.plot(df40.index, df40.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(df40.Close, label='Observations')
plt.plot(df40.LNReg, label='Linear Regression')
plt.plot(df40.NLNReg, label='Nonlinear Regression')
plt.plot(df40.LSTM, label='LSTM')
plt.plot(df40.Arima, label='ARIMA')
plt.plot(df40.Prophet, label='Prophet')
plt.ylabel('Close')
plt.xlabel('Date')
plt.legend()
plt.show()
